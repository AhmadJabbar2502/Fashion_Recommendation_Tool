# %%
import os
import shutil
from pathlib import Path
from pymongo import MongoClient
from bson import ObjectId
from PIL import Image
import io

# %%
MONGODB_URI = "mongodb+srv://AhmadJb:F6ndXplHiGRKfR56@products.btwmn.mongodb.net/"

try:
    client = MongoClient(MONGODB_URI)
    # Ping the database to check if the connection is successful
    client.admin.command('ping')
    print("Connected to MongoDB successfully!")
except Exception as e:
    print("Failed to connect to MongoDB:", e)
    exit(1)
    
db = client["LLMs_Project"]
collection = db["Products"]
# Out:
# Connected to MongoDB successfully!

# %%
images_dir = Path('../frontend/public/images')
count = 1
try:
    # Fetch products from the MongoDB collection
    products = collection.find()

    for product in products:
        product_folder = images_dir / str(product["_id"])

        # Create the folder for the product if it doesn't exist
        product_folder.mkdir(parents=True, exist_ok=True)

        # Save each image (if not already saved)
        for index, image_buffer in enumerate(product["images"]):
            image_path = product_folder / f"image{index + 1}.jpg"

            # Check if the image already exists to prevent duplicates
            if not image_path.exists():
                # Convert the image buffer (assuming it's a binary buffer) to an image and save
                image = Image.open(io.BytesIO(image_buffer))
                image.save(image_path)
        print("Count: ", count,  " --- Images of ", product["_id"], " saved \n")
        count = count + 1

    # Respond with the products (or any other desired result)
    print("Products and images saved successfully.")
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Count:  1  --- Images of  67364eed6b5f370c97b33da0  saved
#
# Count:  2  --- Images of  67364eee6b5f370c97b33da1  saved
#
# Count:  3  --- Images of  67364eee6b5f370c97b33da2  saved
#
# Count:  4  --- Images of  67364eee6b5f370c97b33da3  saved
#
# Count:  5  --- Images of  67364eee6b5f370c97b33da4  saved
#
# Count:  6  --- Images of  67364eee6b5f370c97b33da5  saved
#
# Count:  7  --- Images of  67364eee6b5f370c97b33da6  saved
#
# Count:  8  --- Images of  67364eee6b5f370c97b33da7  saved
#
# Count:  9  --- Images of  67364eef6b5f370c97b33da8  saved
#
# Count:  10  --- Images of  67364eef6b5f370c97b33da9  saved
#
# Count:  11  --- Images of  67364eef6b5f370c97b33daa  saved
#
# Count:  12  --- Images of  67364eef6b5f370c97b33dab  saved
#
# Count:  13  --- Images of  67364eef6b5f370c97b33dac  saved
#
# Count:  14  --- Images of  67364ef06b5f370c97b33dad  saved
#
# Count:  15  --- Images of  67364ef06b5f370c97b33dae  saved
#
# Count:  16  --- Images of  67364ef06b5f370c97b33daf  saved
#
# Count:  17  --- Images of  67364ef06b5f370c97b33db0  saved
#
# Count:  18  --- Images of  67364ef06b5f370c97b33db1  saved
#
# Count:  19  --- Images of  67364ef06b5f370c97b33db2  saved
#
# Count:  20  --- Images of  67364ef16b5f370c97b33db3  saved
#
# Count:  21  --- Images of  67364ef16b5f370c97b33db4  saved
#
# Count:  22  --- Images of  67364ef16b5f370c97b33db5  saved
#
# Count:  23  --- Images of  67364ef16b5f370c97b33db6  saved
#
# Count:  24  --- Images of  67364ef16b5f370c97b33db7  saved
#
# Count:  25  --- Images of  67364ef26b5f370c97b33db8  saved
#
# Count:  26  --- Images of  67364ef36b5f370c97b33db9  saved
#
# Count:  27  --- Images of  67364ef46b5f370c97b33dba  saved
#
# Count:  28  --- Images of  67364ef56b5f370c97b33dbb  saved
#
# Count:  29  --- Images of  67364ef56b5f370c97b33dbc  saved
#
# Count:  30  --- Images of  67364ef66b5f370c97b33dbd  saved
#
# Count:  31  --- Images of  67364ef66b5f370c97b33dbe  saved
#
# Count:  32  --- Images of  67364ef66b5f370c97b33dbf  saved
#
# Count:  33  --- Images of  67364ef76b5f370c97b33dc0  saved
#
# Count:  34  --- Images of  67364ef76b5f370c97b33dc1  saved
#
# Count:  35  --- Images of  67364ef76b5f370c97b33dc2  saved
#
# Count:  36  --- Images of  67364ef76b5f370c97b33dc3  saved
#
# Count:  37  --- Images of  67364ef86b5f370c97b33dc4  saved
#
# Count:  38  --- Images of  67364ef86b5f370c97b33dc5  saved
#
# Count:  39  --- Images of  67364ef86b5f370c97b33dc6  saved
#
# Count:  40  --- Images of  67364ef96b5f370c97b33dc7  saved
#
# Count:  41  --- Images of  67364ef96b5f370c97b33dc8  saved
#
# Count:  42  --- Images of  67364ef96b5f370c97b33dc9  saved
#
# Count:  43  --- Images of  67364ef96b5f370c97b33dca  saved
#
# Count:  44  --- Images of  67364efa6b5f370c97b33dcb  saved
#
# Count:  45  --- Images of  67364efa6b5f370c97b33dcc  saved
#
# Count:  46  --- Images of  67364efa6b5f370c97b33dcd  saved
#
# Count:  47  --- Images of  67364efb6b5f370c97b33dce  saved
#
# Count:  48  --- Images of  67364efb6b5f370c97b33dcf  saved
#
# Count:  49  --- Images of  67364efb6b5f370c97b33dd0  saved
#
# Count:  50  --- Images of  67364efb6b5f370c97b33dd1  saved
#
# Count:  51  --- Images of  67364efc6b5f370c97b33dd2  saved
#
# Count:  52  --- Images of  67364efc6b5f370c97b33dd3  saved
#
# Count:  53  --- Images of  67364efc6b5f370c97b33dd4  saved
#
# Count:  54  --- Images of  67364efc6b5f370c97b33dd5  saved
#
# Count:  55  --- Images of  67364efc6b5f370c97b33dd6  saved
#
# Count:  56  --- Images of  67364efd6b5f370c97b33dd7  saved
#
# Count:  57  --- Images of  67364efd6b5f370c97b33dd8  saved
#
# Count:  58  --- Images of  67364efd6b5f370c97b33dd9  saved
#
# Count:  59  --- Images of  67364efd6b5f370c97b33dda  saved
#
# Count:  60  --- Images of  67364efd6b5f370c97b33ddb  saved
#
# Count:  61  --- Images of  67364efd6b5f370c97b33ddc  saved
#
# Count:  62  --- Images of  67364efe6b5f370c97b33ddd  saved
#
# Count:  63  --- Images of  67364efe6b5f370c97b33dde  saved
#
# Count:  64  --- Images of  67364efe6b5f370c97b33ddf  saved
#
# Count:  65  --- Images of  67364eff6b5f370c97b33de0  saved
#
# Count:  66  --- Images of  67364eff6b5f370c97b33de1  saved
#
# Count:  67  --- Images of  67364eff6b5f370c97b33de2  saved
#
# Count:  68  --- Images of  67364eff6b5f370c97b33de3  saved
#
# Count:  69  --- Images of  67364eff6b5f370c97b33de4  saved
#
# Count:  70  --- Images of  67364eff6b5f370c97b33de5  saved
#
# Count:  71  --- Images of  67364f006b5f370c97b33de6  saved
#
# Count:  72  --- Images of  67364f006b5f370c97b33de7  saved
#
# Count:  73  --- Images of  67364f006b5f370c97b33de8  saved
#
# Count:  74  --- Images of  67364f006b5f370c97b33de9  saved
#
# Count:  75  --- Images of  67364f006b5f370c97b33dea  saved
#
# Count:  76  --- Images of  67364f006b5f370c97b33deb  saved
#
# Count:  77  --- Images of  67364f006b5f370c97b33dec  saved
#
# Count:  78  --- Images of  67364f006b5f370c97b33ded  saved
#
# Count:  79  --- Images of  67364f016b5f370c97b33dee  saved
#
# Count:  80  --- Images of  67364f016b5f370c97b33def  saved
#
# Count:  81  --- Images of  67364f016b5f370c97b33df0  saved
#
# Count:  82  --- Images of  67364f016b5f370c97b33df1  saved
#
# Count:  83  --- Images of  67364f016b5f370c97b33df2  saved
#
# Count:  84  --- Images of  67364f026b5f370c97b33df3  saved
#
# Count:  85  --- Images of  67364f026b5f370c97b33df4  saved
#
# Count:  86  --- Images of  67364f026b5f370c97b33df5  saved
#
# Count:  87  --- Images of  67364f026b5f370c97b33df6  saved
#
# Count:  88  --- Images of  67364f036b5f370c97b33df7  saved
#
# Count:  89  --- Images of  67364f036b5f370c97b33df8  saved
#
# Count:  90  --- Images of  67364f036b5f370c97b33df9  saved
#
# Count:  91  --- Images of  67364f036b5f370c97b33dfa  saved
#
# Count:  92  --- Images of  67364f046b5f370c97b33dfb  saved
#
# Count:  93  --- Images of  67364f046b5f370c97b33dfc  saved
#
# Count:  94  --- Images of  67364f046b5f370c97b33dfd  saved
#
# Count:  95  --- Images of  67364f046b5f370c97b33dfe  saved
#
# Count:  96  --- Images of  67364f056b5f370c97b33dff  saved
#
# Count:  97  --- Images of  67364f056b5f370c97b33e00  saved
#
# Count:  98  --- Images of  67364f056b5f370c97b33e01  saved
#
# Count:  99  --- Images of  67364f066b5f370c97b33e02  saved
#
# Count:  100  --- Images of  67364f066b5f370c97b33e03  saved
#
# Count:  101  --- Images of  67364f066b5f370c97b33e04  saved
#
# Count:  102  --- Images of  67364f066b5f370c97b33e05  saved
#
# Count:  103  --- Images of  67364f066b5f370c97b33e06  saved
#
# Count:  104  --- Images of  67364f076b5f370c97b33e07  saved
#
# Count:  105  --- Images of  67364f076b5f370c97b33e08  saved
#
# Count:  106  --- Images of  67364f076b5f370c97b33e09  saved
#
# Count:  107  --- Images of  67364f076b5f370c97b33e0a  saved
#
# Count:  108  --- Images of  67364f076b5f370c97b33e0b  saved
#
# Count:  109  --- Images of  67364f086b5f370c97b33e0c  saved
#
# Count:  110  --- Images of  67364f086b5f370c97b33e0d  saved
#
# Count:  111  --- Images of  67364f086b5f370c97b33e0e  saved
#
# Count:  112  --- Images of  67364f086b5f370c97b33e0f  saved
#
# Count:  113  --- Images of  67364f096b5f370c97b33e10  saved
#
# Count:  114  --- Images of  67364f096b5f370c97b33e11  saved
#
# Count:  115  --- Images of  67364f096b5f370c97b33e12  saved
#
# Count:  116  --- Images of  67364f096b5f370c97b33e13  saved
#
# Count:  117  --- Images of  67364f096b5f370c97b33e14  saved
#
# Count:  118  --- Images of  67364f096b5f370c97b33e15  saved
#
# Count:  119  --- Images of  67364f0a6b5f370c97b33e16  saved
#
# Count:  120  --- Images of  67364f0a6b5f370c97b33e17  saved
#
# Count:  121  --- Images of  67364f0a6b5f370c97b33e18  saved
#
# Count:  122  --- Images of  67364f0a6b5f370c97b33e19  saved
#
# Count:  123  --- Images of  67364f0a6b5f370c97b33e1a  saved
#
# Count:  124  --- Images of  67364f0a6b5f370c97b33e1b  saved
#
# Count:  125  --- Images of  67364f0b6b5f370c97b33e1c  saved
#
# Count:  126  --- Images of  67364f0b6b5f370c97b33e1d  saved
#
# Count:  127  --- Images of  67364f0b6b5f370c97b33e1e  saved
#
# Count:  128  --- Images of  67364f0b6b5f370c97b33e1f  saved
#
# Count:  129  --- Images of  67364f0c6b5f370c97b33e20  saved
#
# Count:  130  --- Images of  67364f0c6b5f370c97b33e21  saved
#
# Count:  131  --- Images of  67364f0c6b5f370c97b33e22  saved
#
# Count:  132  --- Images of  67364f0c6b5f370c97b33e23  saved
#
# Count:  133  --- Images of  67364f0d6b5f370c97b33e24  saved
#
# Count:  134  --- Images of  67364f0d6b5f370c97b33e25  saved
#
# Count:  135  --- Images of  67364f0d6b5f370c97b33e26  saved
#
# Count:  136  --- Images of  67364f0d6b5f370c97b33e27  saved
#
# Count:  137  --- Images of  67364f0e6b5f370c97b33e28  saved
#
# Count:  138  --- Images of  67364f0e6b5f370c97b33e29  saved
#
# Count:  139  --- Images of  67364f0e6b5f370c97b33e2a  saved
#
# Count:  140  --- Images of  67364f0e6b5f370c97b33e2b  saved
#
# Count:  141  --- Images of  67364f0f6b5f370c97b33e2c  saved
#
# Count:  142  --- Images of  67364f0f6b5f370c97b33e2d  saved
#
# Count:  143  --- Images of  67364f0f6b5f370c97b33e2e  saved
#
# Count:  144  --- Images of  67364f0f6b5f370c97b33e2f  saved
#
# Count:  145  --- Images of  67364f0f6b5f370c97b33e30  saved
#
# Count:  146  --- Images of  67364f0f6b5f370c97b33e31  saved
#
# Count:  147  --- Images of  67364f106b5f370c97b33e32  saved
#
# Count:  148  --- Images of  67364f106b5f370c97b33e33  saved
#
# Count:  149  --- Images of  67364f106b5f370c97b33e34  saved
#
# Count:  150  --- Images of  67364f106b5f370c97b33e35  saved
#
# Count:  151  --- Images of  67364f106b5f370c97b33e36  saved
#
# Count:  152  --- Images of  67364f116b5f370c97b33e37  saved
#
# Count:  153  --- Images of  67364f116b5f370c97b33e38  saved
#
# Count:  154  --- Images of  67364f116b5f370c97b33e39  saved
#
# Count:  155  --- Images of  67364f116b5f370c97b33e3a  saved
#
# Count:  156  --- Images of  67364f116b5f370c97b33e3b  saved
#
# Count:  157  --- Images of  67364f116b5f370c97b33e3c  saved
#
# Count:  158  --- Images of  67364f126b5f370c97b33e3d  saved
#
# Count:  159  --- Images of  67364f126b5f370c97b33e3e  saved
#
# Count:  160  --- Images of  673753effd76308feadf785d  saved
#
# Count:  161  --- Images of  673753f0fd76308feadf785e  saved
#
# Count:  162  --- Images of  673753f0fd76308feadf785f  saved
#
# Count:  163  --- Images of  673753f0fd76308feadf7860  saved
#
# Count:  164  --- Images of  673753f1fd76308feadf7861  saved
#
# Count:  165  --- Images of  673753f2fd76308feadf7862  saved
#
# Count:  166  --- Images of  673753f2fd76308feadf7863  saved
#
# Count:  167  --- Images of  673753f3fd76308feadf7864  saved
#
# Count:  168  --- Images of  673753f3fd76308feadf7865  saved
#
# Count:  169  --- Images of  673753f4fd76308feadf7866  saved
#
# Count:  170  --- Images of  673753f4fd76308feadf7867  saved
#
# Count:  171  --- Images of  673753f4fd76308feadf7868  saved
#
# Count:  172  --- Images of  673753f5fd76308feadf7869  saved
#
# Count:  173  --- Images of  673753f5fd76308feadf786a  saved
#
# Count:  174  --- Images of  673753f5fd76308feadf786b  saved
#
# Count:  175  --- Images of  673753f6fd76308feadf786c  saved
#
# Count:  176  --- Images of  673753f7fd76308feadf786d  saved
#
# Count:  177  --- Images of  673753f7fd76308feadf786e  saved
#
# Count:  178  --- Images of  673753f9fd76308feadf786f  saved
#
# Count:  179  --- Images of  673753f9fd76308feadf7870  saved
#
# Count:  180  --- Images of  673753f9fd76308feadf7871  saved
#
# Count:  181  --- Images of  673753fafd76308feadf7872  saved
#
# Count:  182  --- Images of  673753fbfd76308feadf7873  saved
#
# Count:  183  --- Images of  673753fbfd76308feadf7874  saved
#
# Count:  184  --- Images of  673753fbfd76308feadf7875  saved
#
# Count:  185  --- Images of  673753fbfd76308feadf7876  saved
#
# Count:  186  --- Images of  673753fbfd76308feadf7877  saved
#
# Count:  187  --- Images of  673753fbfd76308feadf7878  saved
#
# Count:  188  --- Images of  673753fcfd76308feadf7879  saved
#
# Count:  189  --- Images of  67375659fd76308feadf787b  saved
#
# Count:  190  --- Images of  67375659fd76308feadf787c  saved
#
# Count:  191  --- Images of  67375659fd76308feadf787d  saved
#
# Count:  192  --- Images of  6737565afd76308feadf787e  saved
#
# Count:  193  --- Images of  6737565afd76308feadf787f  saved
#
# Count:  194  --- Images of  6737565afd76308feadf7880  saved
#
# Count:  195  --- Images of  6737565afd76308feadf7881  saved
#
# Count:  196  --- Images of  6737565bfd76308feadf7882  saved
#
# Count:  197  --- Images of  6737565bfd76308feadf7883  saved
#
# Count:  198  --- Images of  6737565bfd76308feadf7884  saved
#
# Count:  199  --- Images of  6737565bfd76308feadf7885  saved
#
# Count:  200  --- Images of  6737565bfd76308feadf7886  saved
#
# Count:  201  --- Images of  6737565bfd76308feadf7887  saved
#
# Count:  202  --- Images of  6737565cfd76308feadf7888  saved
#
# Count:  203  --- Images of  6737565cfd76308feadf7889  saved
#
# Count:  204  --- Images of  6737565cfd76308feadf788a  saved
#
# Count:  205  --- Images of  6737565cfd76308feadf788b  saved
#
# Count:  206  --- Images of  6737565cfd76308feadf788c  saved
#
# Count:  207  --- Images of  6737565dfd76308feadf788d  saved
#
# Count:  208  --- Images of  6737565dfd76308feadf788e  saved
#
# Count:  209  --- Images of  6737565dfd76308feadf788f  saved
#
# Count:  210  --- Images of  6737565dfd76308feadf7890  saved
#
# Count:  211  --- Images of  6737565dfd76308feadf7891  saved
#
# Count:  212  --- Images of  6737565efd76308feadf7892  saved
#
# Count:  213  --- Images of  6737565efd76308feadf7893  saved
#
# Count:  214  --- Images of  6737565efd76308feadf7894  saved
#
# Count:  215  --- Images of  6737565efd76308feadf7895  saved
#
# Count:  216  --- Images of  6737565efd76308feadf7896  saved
#
# Count:  217  --- Images of  6737565ffd76308feadf7897  saved
#
# Count:  218  --- Images of  6737565ffd76308feadf7898  saved
#
# Count:  219  --- Images of  6737565ffd76308feadf7899  saved
#
# Count:  220  --- Images of  67375660fd76308feadf789a  saved
#
# Count:  221  --- Images of  67375660fd76308feadf789b  saved
#
# Count:  222  --- Images of  67375660fd76308feadf789c  saved
#
# Count:  223  --- Images of  67375660fd76308feadf789d  saved
#
# Count:  224  --- Images of  67375661fd76308feadf789e  saved
#
# Count:  225  --- Images of  67375661fd76308feadf789f  saved
#
# Count:  226  --- Images of  67375661fd76308feadf78a0  saved
#
# Count:  227  --- Images of  67375662fd76308feadf78a1  saved
#
# Count:  228  --- Images of  67376d9afd76308feadf78a3  saved
#
# Count:  229  --- Images of  67376d9bfd76308feadf78a4  saved
#
# Count:  230  --- Images of  67376d9cfd76308feadf78a5  saved
#
# Count:  231  --- Images of  67376d9dfd76308feadf78a6  saved
#
# Count:  232  --- Images of  67376d9dfd76308feadf78a7  saved
#
# Count:  233  --- Images of  67376d9efd76308feadf78a8  saved
#
# Count:  234  --- Images of  67376d9efd76308feadf78a9  saved
#
# Count:  235  --- Images of  67376d9efd76308feadf78aa  saved
#
# Count:  236  --- Images of  67376d9ffd76308feadf78ab  saved
#
# Count:  237  --- Images of  67376d9ffd76308feadf78ac  saved
#
# Count:  238  --- Images of  67376da0fd76308feadf78ad  saved
#
# Count:  239  --- Images of  67376da0fd76308feadf78ae  saved
#
# Count:  240  --- Images of  67376da1fd76308feadf78af  saved
#
# Count:  241  --- Images of  67376da2fd76308feadf78b0  saved
#
# Count:  242  --- Images of  67376da2fd76308feadf78b1  saved
#
# Count:  243  --- Images of  67376da3fd76308feadf78b2  saved
#
# Count:  244  --- Images of  67376da3fd76308feadf78b3  saved
#
# Count:  245  --- Images of  67376da4fd76308feadf78b4  saved
#
# Count:  246  --- Images of  67376da4fd76308feadf78b5  saved
#
# Count:  247  --- Images of  67376da5fd76308feadf78b6  saved
#
# Count:  248  --- Images of  67376da6fd76308feadf78b7  saved
#
# Count:  249  --- Images of  67376da6fd76308feadf78b8  saved
#
# Count:  250  --- Images of  67376da7fd76308feadf78b9  saved
#
# Count:  251  --- Images of  67376da7fd76308feadf78ba  saved
#
# Count:  252  --- Images of  67376da8fd76308feadf78bb  saved
#
# Count:  253  --- Images of  67376da8fd76308feadf78bc  saved
#
# Count:  254  --- Images of  67376da9fd76308feadf78bd  saved
#
# Count:  255  --- Images of  67376da9fd76308feadf78be  saved
#
# Count:  256  --- Images of  67376dabfd76308feadf78bf  saved
#
# Count:  257  --- Images of  67376dacfd76308feadf78c0  saved
#
# Count:  258  --- Images of  67376dadfd76308feadf78c1  saved
#
# Count:  259  --- Images of  67376dadfd76308feadf78c2  saved
#
# Count:  260  --- Images of  67376dadfd76308feadf78c3  saved
#
# Count:  261  --- Images of  67376daefd76308feadf78c4  saved
#
# Count:  262  --- Images of  67376daffd76308feadf78c5  saved
#
# Count:  263  --- Images of  67376db0fd76308feadf78c6  saved
#
# Count:  264  --- Images of  67376db0fd76308feadf78c7  saved
#
# Count:  265  --- Images of  67376db1fd76308feadf78c8  saved
#
# Count:  266  --- Images of  67376db2fd76308feadf78c9  saved
#
# Count:  267  --- Images of  67376db4fd76308feadf78ca  saved
#
# Count:  268  --- Images of  67376db7fd76308feadf78cb  saved
#
# Count:  269  --- Images of  67376db9fd76308feadf78cc  saved
#
# Count:  270  --- Images of  67376dbafd76308feadf78cd  saved
#
# Count:  271  --- Images of  67376dbbfd76308feadf78ce  saved
#
# Count:  272  --- Images of  67376dbcfd76308feadf78cf  saved
#
# Count:  273  --- Images of  67376dbdfd76308feadf78d0  saved
#
# Count:  274  --- Images of  67376dbefd76308feadf78d1  saved
#
# Count:  275  --- Images of  67376dbefd76308feadf78d2  saved
#
# Count:  276  --- Images of  67376dbffd76308feadf78d3  saved
#
# Count:  277  --- Images of  67376dc0fd76308feadf78d4  saved
#
# Count:  278  --- Images of  67376dc0fd76308feadf78d5  saved
#
# Count:  279  --- Images of  67376dc1fd76308feadf78d6  saved
#
# Count:  280  --- Images of  67376dc2fd76308feadf78d7  saved
#
# Count:  281  --- Images of  67376dc3fd76308feadf78d8  saved
#
# Count:  282  --- Images of  67376dc3fd76308feadf78d9  saved
#
# Count:  283  --- Images of  67376dc4fd76308feadf78da  saved
#
# Count:  284  --- Images of  67376dc4fd76308feadf78db  saved
#
# Count:  285  --- Images of  67376dc5fd76308feadf78dc  saved
#
# Count:  286  --- Images of  67376dc6fd76308feadf78dd  saved
#
# Count:  287  --- Images of  67376dc7fd76308feadf78de  saved
#
# Count:  288  --- Images of  67376dc8fd76308feadf78df  saved
#
# Count:  289  --- Images of  67376dc9fd76308feadf78e0  saved
#
# Count:  290  --- Images of  67376dc9fd76308feadf78e1  saved
#
# Count:  291  --- Images of  67376dcafd76308feadf78e2  saved
#
# Count:  292  --- Images of  67376dcafd76308feadf78e3  saved
#
# Count:  293  --- Images of  67376dcbfd76308feadf78e4  saved
#
# Count:  294  --- Images of  67376dcbfd76308feadf78e5  saved
#
# Count:  295  --- Images of  67376dccfd76308feadf78e6  saved
#
# Count:  296  --- Images of  67376dcdfd76308feadf78e7  saved
#
# Count:  297  --- Images of  67376dcdfd76308feadf78e8  saved
#
# Count:  298  --- Images of  67376dcefd76308feadf78e9  saved
#
# Count:  299  --- Images of  67376dcefd76308feadf78ea  saved
#
# Count:  300  --- Images of  67376dcffd76308feadf78eb  saved
#
# Count:  301  --- Images of  67376dcffd76308feadf78ec  saved
#
# Count:  302  --- Images of  67376dcffd76308feadf78ed  saved
#
# Count:  303  --- Images of  67376dd0fd76308feadf78ee  saved
#
# Count:  304  --- Images of  67376dd0fd76308feadf78ef  saved
#
# Count:  305  --- Images of  67376dd0fd76308feadf78f0  saved
#
# Count:  306  --- Images of  67376dd1fd76308feadf78f1  saved
#
# Count:  307  --- Images of  67376dd1fd76308feadf78f2  saved
#
# Count:  308  --- Images of  67376dd3fd76308feadf78f3  saved
#
# Count:  309  --- Images of  67376dd4fd76308feadf78f4  saved
#
# Count:  310  --- Images of  67376dd5fd76308feadf78f5  saved
#
# Count:  311  --- Images of  67376dd6fd76308feadf78f6  saved
#
# Count:  312  --- Images of  67376dd7fd76308feadf78f7  saved
#
# Count:  313  --- Images of  67376dd7fd76308feadf78f8  saved
#
# Count:  314  --- Images of  67376dd8fd76308feadf78f9  saved
#
# Count:  315  --- Images of  67376dd9fd76308feadf78fa  saved
#
# Count:  316  --- Images of  67376dd9fd76308feadf78fb  saved
#
# Count:  317  --- Images of  67376ddafd76308feadf78fc  saved
#
# Count:  318  --- Images of  67376ddafd76308feadf78fd  saved
#
# Count:  319  --- Images of  67376ddafd76308feadf78fe  saved
#
# Count:  320  --- Images of  67376ddafd76308feadf78ff  saved
#
# Count:  321  --- Images of  67376ddbfd76308feadf7900  saved
#
# Count:  322  --- Images of  67376ddcfd76308feadf7901  saved
#
# Count:  323  --- Images of  67376ddcfd76308feadf7902  saved
#
# Count:  324  --- Images of  67376dddfd76308feadf7903  saved
#
# Count:  325  --- Images of  67376dddfd76308feadf7904  saved
#
# Count:  326  --- Images of  67376ddefd76308feadf7905  saved
#
# Count:  327  --- Images of  67376ddefd76308feadf7906  saved
#
# Count:  328  --- Images of  67376ddffd76308feadf7907  saved
#
# Count:  329  --- Images of  67376de0fd76308feadf7908  saved
#
# Count:  330  --- Images of  67376de1fd76308feadf7909  saved
#
# Count:  331  --- Images of  67376de3fd76308feadf790a  saved
#
# Count:  332  --- Images of  67376de4fd76308feadf790b  saved
#
# Count:  333  --- Images of  67376de5fd76308feadf790c  saved
#
# Count:  334  --- Images of  67376de6fd76308feadf790d  saved
#
# Count:  335  --- Images of  67376de6fd76308feadf790e  saved
#
# Count:  336  --- Images of  67376de7fd76308feadf790f  saved
#
# Count:  337  --- Images of  67376de7fd76308feadf7910  saved
#
# Count:  338  --- Images of  67376de8fd76308feadf7911  saved
#
# Count:  339  --- Images of  67376de9fd76308feadf7912  saved
#
# Count:  340  --- Images of  67376de9fd76308feadf7913  saved
#
# Count:  341  --- Images of  67376de9fd76308feadf7914  saved
#
# Count:  342  --- Images of  67376deafd76308feadf7915  saved
#
# Count:  343  --- Images of  67376deafd76308feadf7916  saved
#
# Count:  344  --- Images of  67376deafd76308feadf7917  saved
#
# Count:  345  --- Images of  67376debfd76308feadf7918  saved
#
# Count:  346  --- Images of  67376decfd76308feadf7919  saved
#
# Count:  347  --- Images of  67376decfd76308feadf791a  saved
#
# Count:  348  --- Images of  67376dedfd76308feadf791b  saved
#
# Count:  349  --- Images of  67376deefd76308feadf791c  saved
#
# Count:  350  --- Images of  67376deffd76308feadf791d  saved
#
# Count:  351  --- Images of  67376df0fd76308feadf791e  saved
#
# Count:  352  --- Images of  67376df1fd76308feadf791f  saved
#
# Count:  353  --- Images of  67376df1fd76308feadf7920  saved
#
# Count:  354  --- Images of  67376df2fd76308feadf7921  saved
#
# Count:  355  --- Images of  67376df2fd76308feadf7922  saved
#
# Count:  356  --- Images of  67376df3fd76308feadf7923  saved
#
# Count:  357  --- Images of  67376df3fd76308feadf7924  saved
#
# Count:  358  --- Images of  67376df4fd76308feadf7925  saved
#
# Count:  359  --- Images of  67376df4fd76308feadf7926  saved
#
# Count:  360  --- Images of  67376df5fd76308feadf7927  saved
#
# Count:  361  --- Images of  67376df6fd76308feadf7928  saved
#
# Count:  362  --- Images of  67376df6fd76308feadf7929  saved
#
# Count:  363  --- Images of  67376df8fd76308feadf792a  saved
#
# Count:  364  --- Images of  67376df8fd76308feadf792b  saved
#
# Count:  365  --- Images of  67376df8fd76308feadf792c  saved
#
# Count:  366  --- Images of  67376df9fd76308feadf792d  saved
#
# Count:  367  --- Images of  67376df9fd76308feadf792e  saved
#
# Count:  368  --- Images of  67376dfafd76308feadf792f  saved
#
# Count:  369  --- Images of  67376dfafd76308feadf7930  saved
#
# Count:  370  --- Images of  67376dfafd76308feadf7931  saved
#
# Count:  371  --- Images of  67376dfbfd76308feadf7932  saved
#
# Count:  372  --- Images of  67376dfbfd76308feadf7933  saved
#
# Count:  373  --- Images of  67376dfcfd76308feadf7934  saved
#
# Count:  374  --- Images of  67376dfcfd76308feadf7935  saved
#
# Count:  375  --- Images of  67376dfefd76308feadf7936  saved
#
# Count:  376  --- Images of  67376dfefd76308feadf7937  saved
#
# Count:  377  --- Images of  67376dfefd76308feadf7938  saved
#
# Count:  378  --- Images of  67376dfffd76308feadf7939  saved
#
# Count:  379  --- Images of  67376e00fd76308feadf793a  saved
#
# Count:  380  --- Images of  67376e00fd76308feadf793b  saved
#
# Count:  381  --- Images of  67376e01fd76308feadf793c  saved
#
# Count:  382  --- Images of  67376e01fd76308feadf793d  saved
#
# Count:  383  --- Images of  67376e02fd76308feadf793e  saved
#
# Count:  384  --- Images of  67376e02fd76308feadf793f  saved
#
# Count:  385  --- Images of  67376e03fd76308feadf7940  saved
#
# Count:  386  --- Images of  67376e03fd76308feadf7941  saved
#
# Count:  387  --- Images of  67376e04fd76308feadf7942  saved
#
# Count:  388  --- Images of  67376e05fd76308feadf7943  saved
#
# Count:  389  --- Images of  67376e05fd76308feadf7944  saved
#
# Count:  390  --- Images of  67376e06fd76308feadf7945  saved
#
# Count:  391  --- Images of  67376e06fd76308feadf7946  saved
#
# Count:  392  --- Images of  67376e07fd76308feadf7947  saved
#
# Count:  393  --- Images of  67376e07fd76308feadf7948  saved
#
# Count:  394  --- Images of  67376e08fd76308feadf7949  saved
#
# Count:  395  --- Images of  67376e08fd76308feadf794a  saved
#
# Count:  396  --- Images of  67376e09fd76308feadf794b  saved
#
# Count:  397  --- Images of  67376e09fd76308feadf794c  saved
#
# Count:  398  --- Images of  67376e0afd76308feadf794d  saved
#
# Count:  399  --- Images of  67376e0bfd76308feadf794e  saved
#
# Count:  400  --- Images of  67376e0bfd76308feadf794f  saved
#
# Count:  401  --- Images of  67376e0cfd76308feadf7950  saved
#
# Count:  402  --- Images of  67376e0dfd76308feadf7951  saved
#
# Count:  403  --- Images of  67376e0dfd76308feadf7952  saved
#
# Count:  404  --- Images of  67376e0efd76308feadf7953  saved
#
# Count:  405  --- Images of  67376e0ffd76308feadf7954  saved
#
# Count:  406  --- Images of  67376e0ffd76308feadf7955  saved
#
# Count:  407  --- Images of  67376e10fd76308feadf7956  saved
#
# Count:  408  --- Images of  67376e11fd76308feadf7957  saved
#
# Count:  409  --- Images of  67376e11fd76308feadf7958  saved
#
# Count:  410  --- Images of  67376e12fd76308feadf7959  saved
#
# Count:  411  --- Images of  67376e13fd76308feadf795a  saved
#
# Count:  412  --- Images of  67376e14fd76308feadf795b  saved
#
# Count:  413  --- Images of  67376e15fd76308feadf795c  saved
#
# Count:  414  --- Images of  67376e15fd76308feadf795d  saved
#
# Count:  415  --- Images of  67376e16fd76308feadf795e  saved
#
# Count:  416  --- Images of  67376e17fd76308feadf795f  saved
#
# Count:  417  --- Images of  67376e17fd76308feadf7960  saved
#
# Count:  418  --- Images of  67376e18fd76308feadf7961  saved
#
# Count:  419  --- Images of  67376e19fd76308feadf7962  saved
#
# Count:  420  --- Images of  67376e19fd76308feadf7963  saved
#
# Count:  421  --- Images of  67376e1bfd76308feadf7964  saved
#
# Count:  422  --- Images of  67376e1cfd76308feadf7965  saved
#
# Count:  423  --- Images of  67376e1cfd76308feadf7966  saved
#
# Count:  424  --- Images of  67376e1dfd76308feadf7967  saved
#
# Count:  425  --- Images of  67376e1dfd76308feadf7968  saved
#
# Count:  426  --- Images of  67376e1efd76308feadf7969  saved
#
# Count:  427  --- Images of  67376e1efd76308feadf796a  saved
#
# Count:  428  --- Images of  67376e1efd76308feadf796b  saved
#
# Count:  429  --- Images of  67376e1ffd76308feadf796c  saved
#
# Count:  430  --- Images of  67376e20fd76308feadf796d  saved
#
# Count:  431  --- Images of  67376e20fd76308feadf796e  saved
#
# Count:  432  --- Images of  67376e21fd76308feadf796f  saved
#
# Count:  433  --- Images of  67376e22fd76308feadf7970  saved
#
# Count:  434  --- Images of  67376e22fd76308feadf7971  saved
#
# Count:  435  --- Images of  67376e23fd76308feadf7972  saved
#
# Count:  436  --- Images of  67376e24fd76308feadf7973  saved
#
# Count:  437  --- Images of  67376e24fd76308feadf7974  saved
#
# Count:  438  --- Images of  67376e24fd76308feadf7975  saved
#
# Count:  439  --- Images of  67376e25fd76308feadf7976  saved
#
# Count:  440  --- Images of  67376e26fd76308feadf7977  saved
#
# Count:  441  --- Images of  67376e27fd76308feadf7978  saved
#
# Count:  442  --- Images of  67376e28fd76308feadf7979  saved
#
# Count:  443  --- Images of  67376e29fd76308feadf797a  saved
#
# Count:  444  --- Images of  67376e29fd76308feadf797b  saved
#
# Count:  445  --- Images of  67376e2afd76308feadf797c  saved
#
# Count:  446  --- Images of  67376e2afd76308feadf797d  saved
#
# Products and images saved successfully.
